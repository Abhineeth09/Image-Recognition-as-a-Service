# %%
import boto3
ec2 = boto3.resource('ec2')
ec2.Instance('i-0b502debecaaf76ad').start()
# Out:
# ---------------------------------------------------------------------------
# NoRegionError                             Traceback (most recent call last)
# <ipython-input-11-46d818a1477a> in <module>
#       1 import boto3
# ----> 2 ec2 = boto3.resource('ec2')
#       3 ec2.Instance('i-0b502debecaaf76ad').start()
#
# ~/miniconda3/envs/ML/lib/python3.8/site-packages/boto3/__init__.py in resource(*args, **kwargs)
#     100     See :py:meth:`boto3.session.Session.resource`.
#     101     """
# --> 102     return _get_default_session().resource(*args, **kwargs)
#     103
#     104
#
# ~/miniconda3/envs/ML/lib/python3.8/site-packages/boto3/session.py in resource(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config)
#     382         else:
#     383             config = Config(user_agent_extra='Resource')
# --> 384         client = self.client(
# ...
